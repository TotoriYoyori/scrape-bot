# %%
from extract import extract_socrata_csv, extract_socrata_csv_lite

# %%
sample_df = await extract_socrata_csv_lite(data_source_url="https://data.cityofchicago.org/resource/ydr8-5enu.csv")

sample_df
# Out:
#            id     permit_ permit_status permit_milestone  \
# 0     3368573   101046020           NaN              NaN
# 1     3423504   101072844        ACTIVE      INSPECTIONS
# 2     2486241   100498645           NaN              NaN
# 3     2487337   100499294           NaN              NaN
# 4     2490603   100500984           NaN              NaN
# ..        ...         ...           ...              ...
# 995  N2788534  B200445606        ACTIVE      INSPECTIONS
# 996  N2788703  B200445647      COMPLETE         COMPLETE
# 997  N2792802  B200446778        ACTIVE      INSPECTIONS
# 998  N2791355  B200446395      COMPLETE         COMPLETE
# 999  N2788231  B200445537        ACTIVE      INSPECTIONS
#
#                          permit_type             review_type  \
# 0                     PERMIT - SIGNS             SIGN PERMIT
# 1     PERMIT - RENOVATION/ALTERATION               SELF CERT
# 2       PERMIT - EASY PERMIT PROCESS             EASY PERMIT
# ...

# %%
sample_df[[col for col in sample_df.columns if not str(col).startswith("contact_")]].info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 41 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1000 non-null   str
#  1   permit_                 1000 non-null   str
#  2   permit_status           588 non-null    str
#  3   permit_milestone        588 non-null    str
#  4   permit_type             1000 non-null   str
#  5   review_type             1000 non-null   str
#  6   application_start_date  1000 non-null   str
#  7   issue_date              1000 non-null   str
#  8   processing_time         1000 non-null   int64
#  9   street_number           1000 non-null   int64
#  10  street_direction        1000 non-null   str
#  11  street_name             1000 non-null   str
#  12  work_type               214 non-null    str
#  13  work_description        999 non-null    str
#  14  permit_condition        43 non-null     str
# ...
